# %% [markdown]
# # <center> Данный скрипт осуществляет анализ данных пользователей и их комментариев

# %%
# Для выгрузки данных с ВК
import requests
import json
import os
from spisok import slova_key # ключевые слова


# Для обработки полученных данных
import pandas as pd
import numpy as np

# %% [markdown]
# # <center> Подгружаем данные с комментариями и пользователями

# %%
users_data = pd.read_csv('users_data.csv', sep=';', decimal='.')

# %%
users_data
# Out:
#       id_группы  id_поста  id_пользователя  \
# 0     -63683472   2794790        266884711
# 1     -63683472   2794790          9123584
# 2     -63683472   2794790           317899
# 3     -63683472   2794790         40698122
# 4     -63683472   2794790        405251797
# ...         ...       ...              ...
# 3399  -63683472   2788625        438982077
# 3400  -63683472   2788625          4703517
# 3401  -63683472   2788625        356789277
# 3402  -63683472   2788625         69885373
# 3403  -63683472   2788625         36607616
#
#                                             Комментарий         Имя  \
# 0     Да пхд если бк детонирует, особо разницы нету,...       Pavel
# 1     Тупейший пост. Башня танка наиболее уязвимая ч...      Sergey
# 2     Да если рванет, уже пох будет, во всех вариант...  Svyatoslav
# 3                                                   NaN      Kirill
# 4     Лучше всего отношение к людям, стране показыва...       Elena
# ...
